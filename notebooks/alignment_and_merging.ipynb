# %%
import lamindb as ln
import bionty as bt
# Out:
# → connected lamindb: laminlabs/pertdata

# %%
from tools.convert_triplet_artifacts import *
from tools.ingest_xatlas_orion import *

# %%
unprocessed = [
    # GSE81884
    "scperturb/records/13350497/files/XieHon2017.h5ad",
    #
    "scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_RNA.h5ad",
    "scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_protein.h5ad",
    "scperturb/records/13350497/files/PapalexiSatija2021_eccite_protein.h5ad",
    "scperturb/records/13350497/files/PapalexiSatija2021_eccite_RNA.h5ad",
    #
    "scperturb/records/13350497/files/GehringPachter2019.h5ad",
    # GSE106340 , GSE115943
    "scperturb/records/13350497/files/SchiebingerLander2019_GSE115943.h5ad",
    "scperturb/records/13350497/files/SchiebingerLander2019_GSE106340.h5ad",
    # GSE120861
    "scperturb/records/13350497/files/GasperiniShendure2019_atscale.h5ad",
    "scperturb/records/13350497/files/GasperiniShendure2019_highMOI.h5ad",
    "scperturb/records/13350497/files/GasperiniShendure2019_lowMOI.h5ad",
    "parse10m/Parse_10M_PBMC_cytokines",
]

others = [
    "scperturb/sunshine23",
    "scperturb/shifrut18",  # GSE119450
    "DRUG-seq/GSE120222",
    "scperturb/chang22",  # changye2021
    "scperturb/aissa21",  # GSE149383
    "scperturb/datlinger17",  # GSE92872
    "scperturb/datlinger21",  # GSE168620
    "scperturb/frangieh21",
    "scperturb/xu23",
    "scperturb/wessels22",
    "scperturb/zhao21",  # GSE148842
    # GSE124703
    "scperturb/tian21_CRISPRi",
    "scperturb/tian21_CRISPRa",
    # GSE153056
    "scperturb/papalexi21_eccite_arrayed_RNA",
    "scperturb/papalexi21_eccite_RNA",
    # GSE152988
    "scperturb/tian19_day7neuron",
    "scperturb/tian19_iPSC",
    "scperturb/norman19",  # GSE133344
    "scperturb/mcfarland20",
    "ginkgo-datapoints/vcpi",
]

# add gene effect and other features for mcfarland20
# redo the parse10m to follow the same schema as the others

srivatsan = [  # GSE139944
    "scperturb/srivatsan20_sciplex2",
    "scperturb/srivatsan20_sciplex3",
    "scperturb/srivatsan20_sciplex4",
]

# could be merged

gwps = [
    "scperturb/replogle22_K562_gwps",
    "scperturb/replogle22_RPE1",
    # "scperturb/replogle22_K562_essential",
]

adamson = [
    "scperturb/adamson16_GSM2406675_10X001",  # GSE90546
    "scperturb/adamson16_GSM2406677_10X005",
    "scperturb/adamson16_GSM2406681_10X010",
]

# could be merged

nadig = ["scperturb/nadig24_hepg2", "scperturb/nadig24_jurkat"]

# could be merged

dixit = [
    "scperturb/dixit16_K562_TFs_13_days",  # GSE90063
    "scperturb/dixit16_K562_TFs_7_days",
    "scperturb/dixit16_K562_TFs_High_MOI",
]

# could be merged

lincs = [
    # "lincs/phase1/Level2_GEX_delta_n49216x978",
    "lincs/phase1/Level2_GEX_epsilon_n1269922x978",
    "lincs/phase2/Level2_GEX_all_n537590x978",
]
# remaining add lincs Level4 data

tahoe = [
    # "tahoe100m/Tahoe-100M-SCVI-v1/minified_AnnData",
    "tahoe100m/2025-02-25/plate1_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate2_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate3_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate4_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate5_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate6_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate7_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate8_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate9_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate10_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate11_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate12_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate13_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate14_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
]

GSE305979 = [
    "cellarity/GSE305979/GSE305979_day0_raw_counts",
    "cellarity/GSE305979/GSE305979_day1-7_raw_counts",
    "cellarity/GSE305979/GSE305979_day0-7_normalized_counts_with_celltype_annotations",
]

# why does GSE305979_day0-7_normalized_counts contains less cells than the raw counts? maybe some filtering was done?

GSE306429 = [
    "cellarity/GSE306429/GSE306429_combined_vscores",
    "cellarity/GSE306429/GSE306429_combined_demuxed",
]


# GSE305370 = [
#    "cellarity/GSE305370/GSE305370_multiome_alldonors_alldays",
#    "cellarity/GSE305370/GSE305370_citeseq_alldonors_alldays",
# ]
# merge cite and multiome

# compute diff expr (parquet) for all datasets

# check missing annotations (overlap of obs features and unknown or empty fields)

# preprocess by computing quality metrics (mito, ribo, etc) and flagging low quality cells

# compute and find missing annotations (sex, ethnicity, pert library)

# define fingerprints for all datasets (perturbation, cell type, etc)

# get the dna seq for all patients

# compute an embedding (obsm)

# %% [markdown]
# ## Phase 1 — Migrate legacy h5ad artifacts to triplet format
#
# All six unprocessed datasets are migrated to the canonical
# `obs.parquet / X.h5ad / var.parquet` triplet layout via `migrate_h5ad_to_triplet`.

# %%
migrate_h5ad_to_triplet(
    "scperturb/records/13350497/files/XieHon2017.h5ad",
    ln,
    replace_on_instance=True,
    storage=False,
)

# %%
import anndata as ad
import mudata as mu
import tempfile
from pathlib import Path

# the 4 Papalexi files from `unprocessed`
papalexi_paths = unprocessed[1:5]

# load as AnnData from Lamin artifacts
papalexi = {p: ln.Artifact.filter(key__contains=p).one().load() for p in papalexi_paths}

# concat by modality
rna = ad.concat(
    [papalexi[papalexi_paths[0]], papalexi[papalexi_paths[3]]],
    join="outer",
    label="source",
    keys=["eccite_arrayed_RNA", "eccite_RNA"],
    index_unique="-",
)
protein = ad.concat(
    [papalexi[papalexi_paths[1]], papalexi[papalexi_paths[2]]],
    join="outer",
    label="source",
    keys=["eccite_arrayed_protein", "eccite_protein"],
    index_unique="-",
)

# add protein features into RNA obs (few columns, so store as metadata)
protein_df = protein.to_df().reindex(rna.obs_names)
for col in protein_df.columns:
    rna.obs[f"protein_{col}"] = protein_df[col].values

# migrate the single AnnData with protein values in obs
try:
    migrate_h5ad_to_triplet(rna, ln, replace_on_instance=True, storage=False, dataset_prefix="papalexi_eccite_merged")
except TypeError:
    with tempfile.TemporaryDirectory() as td:
        tmp_path = Path(td) / "papalexi_eccite_merged.h5ad"
        rna.write_h5ad(tmp_path)
        migrate_h5ad_to_triplet(
            str(tmp_path), ln, replace_on_instance=True, storage=False
        )
# Out:
# ! run input wasn't tracked, call `ln.track()` and re-run
# ! run input wasn't tracked, call `ln.track()` and re-run
# ! run input wasn't tracked, call `ln.track()` and re-run
# ! run input wasn't tracked, call `ln.track()` and re-run
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 35
#      33 # migrate the single AnnData with protein values in obs
#      34 try:
# ---> 35     migrate_h5ad_to_triplet(rna, ln, replace_on_instance=True, storage=False)
#      36 except TypeError:
#      37     with tempfile.TemporaryDirectory() as td:
#
# File ~/pert-gym/tools/convert_triplet_artifacts.py:94, in migrate_h5ad_to_triplet(dataset_name, db, dataset_prefix, replace_on_instance, storage)
#      92     adata = dataset_name
#      93     if dataset_prefix is None:
# ---> 94         raise ValueError(
#      95             "dataset_prefix is required when dataset_name is an AnnData object."
#      96         )
#      97     prefix = _prefix_from_key(dataset_prefix)
#      98 else:
#
# ValueError: dataset_prefix is required when dataset_name is an AnnData object.

# %%
papalexi[papalexi_paths[0]]
# Out:
# AnnDataAccessor object with n_obs × n_vars = 8984 × 16826
#   constructed for the AnnData object PapalexiSatija2021_eccite_arrayed_RNA.h5ad
#     obs: ['_index', 'cancer', 'cell_line', 'celltype', 'disease', 'gdo_barcode', 'guide_id', 'hto', 'hto_barcode', 'ncounts', 'ngenes', 'nperts', 'organism', 'percent_mito', 'percent_ribo', 'perturbation', 'perturbation_type', 'tissue_type']
#     var: ['ensembl_id', 'gene_symbol', 'ncells', 'ncounts']

# %%
migrate_h5ad_to_triplet(rna, ln, replace_on_instance=True, storage=False, dataset_prefix="papalexi_eccite_merged")
# Out:
# ! no run & transform got linked, call `ln.track()` & re-run
# → writing the in-memory object into cache
# ... uploading Yu9MrXLJk6UD92oB0000.parquet: 100.0%
# ! no run & transform got linked, call `ln.track()` & re-run
# → writing the in-memory object into cache
# ... uploading nlw6aPclhTc6tTsF0000.h5ad: 100.0%
# ! no run & transform got linked, call `ln.track()` & re-run
# → writing the in-memory object into cache
# ... uploading HWIQK1Tva1dqbE3Y0000.parquet: 100.0%
# {'obs': Artifact(uid='Yu9MrXLJk6UD92oB0000', version_tag=None, is_latest=True, key='papalexi_eccite_merged/obs.parquet', description=None, suffix='.parquet', kind='dataset', otype='DataFrame', size=1176312, hash='P4nrtIowcT5Acm4YB4eiUg', n_files=None, n_observations=29713, branch_id=2, created_on_id=2, space_id=1, storage_id=1, run_id=None, schema_id=None, created_by_id=14, created_at=2026-02-26 16:35:23 UTC, is_locked=False),
#  'X': Artifact(uid='nlw6aPclhTc6tTsF0000', version_tag=None, is_latest=True, key='papalexi_eccite_merged/X.h5ad', description=None, suffix='.h5ad', kind='dataset', otype='AnnData', size=743081576, hash='9dtfy-SjInE7u5wICcXG4C', n_files=None, n_observations=29713, branch_id=2, created_on_id=2, space_id=1, storage_id=1, run_id=None, schema_id=None, created_by_id=14, created_at=2026-02-26 16:35:31 UTC, is_locked=False),
#  'var': Artifact(uid='HWIQK1Tva1dqbE3Y0000', version_tag=None, is_latest=True, key='papalexi_eccite_merged/var.parquet', description=None, suffix='.parquet', kind='dataset', otype='DataFrame', size=142766, hash='hHyLT0JTNrJYuW0_u6lorQ', n_files=None, n_observations=18913, branch_id=2, created_on_id=2, space_id=1, storage_id=1, run_id=None, schema_id=None, created_by_id=14, created_at=2026-02-26 16:35:40 UTC, is_locked=False)}

# %%
migrate_h5ad_to_triplet(
    "scperturb/records/13350497/files/GehringPachter2019.h5ad",
    ln,
    replace_on_instance=True,
    storage=False,
)
# parse10m: migrate directly
migrate_h5ad_to_triplet(unprocessed[11], ln, replace_on_instance=True, storage=False)

# %%
def _concat_and_migrate(paths, prefix):
    adatas = [ln.Artifact.filter(key__contains=p).one().load() for p in paths]
    merged = ad.concat(
        adatas,
        join="outer",
        label="source",
        keys=[Path(p).stem for p in paths],
        index_unique="-",
    )
    try:
        migrate_h5ad_to_triplet(merged, ln, replace_on_instance=True, storage=False, dataset_prefix=prefix)
    except TypeError:
        with tempfile.TemporaryDirectory() as td:
            tmp_path = Path(td) / f"{prefix}.h5ad"
            merged.write_h5ad(tmp_path)
            migrate_h5ad_to_triplet(
                str(tmp_path), ln, replace_on_instance=True, storage=False
            )


# GSE106340, GSE115943: concat then migrate
_concat_and_migrate(unprocessed[6:8], prefix="SchiebingerLander2019")

# GSE120861: concat then migrate
_concat_and_migrate(unprocessed[8:11], prefix="GasperiniShendure2019")

# %%
res = (
    ln.Artifact.filter(
        key__contains="scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_RNA.h5ad"
    )
    .one()
    .open()
)
# Out:
# ! run input wasn't tracked, call `ln.track()` and re-run
