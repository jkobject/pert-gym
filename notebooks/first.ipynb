# %% [markdown]
# # Connect to laminlabs/pertdata
#
# This connects to the LaminDB perturbation instance and shows how to load a
# curated AnnData object.

# %%
# If needed, install packages (uncomment):
# %pip install lamindb bionty pertdata
# %lamin init --storage ./pertdata --modules bionty,pertdata
import lamindb as ln
import bionty as bt
from tools.preprocess_collection import latest_by_key
# %reload_ext autoreload
# %autoreload 2

# %%
artifacts_all = list(ln.Artifact.filter().all())
len(artifacts_all)
# Out:
# 413

# %%
artifacts = latest_by_key([a for a in artifacts_all if a.key])
len(artifacts)
# Out:
# 332

# %%
for i in db.Artifact.filter(key__contains="README.md").all():
    print(i.cache())
# Out:
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/arc-ctc-tahoe100/tahoe100m/2025-02-25/README.md
# ... synchronizing rPd3AmzfmA6w9sVd0006.md: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/lamin-us-west-2/H7d9vxvceBoh/.lamindb/rPd3AmzfmA6w9sVd0006.md
# ... synchronizing rPd3AmzfmA6w9sVd0000.md: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/lamin-us-west-2/H7d9vxvceBoh/.lamindb/rPd3AmzfmA6w9sVd0000.md
# ... synchronizing rPd3AmzfmA6w9sVd0005.md: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/lamin-us-west-2/H7d9vxvceBoh/.lamindb/rPd3AmzfmA6w9sVd0005.md
# ... synchronizing README.md: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/lamin-us-west-2/H7d9vxvceBoh/README.md
# ... synchronizing rPd3AmzfmA6w9sVd0003.md: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/lamin-us-west-2/H7d9vxvceBoh/.lamindb/rPd3AmzfmA6w9sVd0003.md
# ... synchronizing GSE305370_README.md.txt: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/ftp.ncbi.nlm.nih.gov/cellarity/GSE305370/GSE305370_README.md.txt
# ... synchronizing rPd3AmzfmA6w9sVd0002.md: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/lamin-us-west-2/H7d9vxvceBoh/.lamindb/rPd3AmzfmA6w9sVd0002.md
# ... synchronizing rPd3AmzfmA6w9sVd0001.md: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/lamin-us-west-2/H7d9vxvceBoh/.lamindb/rPd3AmzfmA6w9sVd0001.md
# ... synchronizing rPd3AmzfmA6w9sVd0004.md: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# /Users/jkobject/Library/Caches/lamindb/lamin-us-west-2/H7d9vxvceBoh/.lamindb/rPd3AmzfmA6w9sVd0004.md

# %%
df = db.Artifact.get(key="df_all__efo__3.80.0__ExperimentalFactor.parquet").load()
# Out:
# ... synchronizing df_all__efo__3.80.0__ExperimentalFactor.parquet: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run

# %%
df
# Out:
#                              name  \
# ontology_id
# EFO:0000001   experimental factor
# EFO:0000002               CS57511
# EFO:0000003               CS57512
# EFO:0000004               CS57515
# EFO:0000005               CS57520
# ...                           ...
# EFO:1002047         spotted fever
# EFO:1002048        kidney failure
# EFO:1002049    glomerular disease
# EFO:1002050             nephritis
# EFO:1002051  facial nerve disease
#
#                                                     definition  \
# ontology_id
# EFO:0000001  An Experimental Factor In Array Express Which ...
# EFO:0000002  Cs57511 Is An Arabidopsis Thaliana Strain As D...
# EFO:0000003  Cs57512 Is An Arabidopsis Thaliana Strain As D...
# EFO:0000004  Cs57515 Is An Arabidopsis Thaliana Strain As D...
# EFO:0000005  Cs57520 Is An Arabidopsis Thaliana Strain As D...
# ...                                                        ...
# EFO:1002047  A Type Of Tick-Borne Disease Which Presents On...
# EFO:1002048  An Acute Or Chronic Condition That Is Characte...
# EFO:1002049          A Disease Involving The Renal Glomerulus.
# EFO:1002050                      Inflammation Of Renal Tissue.
# EFO:1002051              A Disease Involving The Facial Nerve.
#
#                                                       synonyms  \
# ontology_id
# EFO:0000001                                 ExperimentalFactor
# EFO:0000002                                               None
# EFO:0000003                                               None
# EFO:0000004                                               None
# EFO:0000005                                               None
# ...                                                        ...
# EFO:1002047  spotted fever|spotted fever rickettsiae diseas...
# EFO:1002048  renal insufficiency|failure, renal|kidney fail...
# EFO:1002049  disease of renal glomerulus|renal glomerulus d...
# EFO:1002050  nephritis|inflammation of kidney|kidney inflam...
# EFO:1002051  disorder of facial nerve|facial nerve disease ...
#
#                                 parents
# ontology_id
# EFO:0000001                          []
# EFO:0000002                          []
# EFO:0000003                          []
# EFO:0000004                          []
# EFO:0000005                          []
# ...                                 ...
# EFO:1002047               [EFO:1001128]
# EFO:1002048               [EFO:0003086]
# EFO:1002049               [EFO:0003086]
# EFO:1002050  [EFO:0009903, EFO:0003086]
# EFO:1002051               [EFO:0009387]
#
# [18249 rows x 4 columns]

# %%
elem = [
    "ZhaoSims2021",
    "ChangYe",
    "ShifrutMarson2018",
    "SchiebingerLander2019",
    "XieHon2017",
    "XuCao2023",
    "PapalexiSatija2021",
    "GehringPachter2019",
    "GasperiniShendure2019",
    "sanja",
]

# %%
for art in artifacts:
    if any(e in art.key for e in elem):
        print(art.key)
# Out:
# scperturb/records/13350497/files/GasperiniShendure2019_atscale.h5ad
# scperturb/records/13350497/files/GasperiniShendure2019_highMOI.h5ad
# scperturb/records/13350497/files/ZhaoSims2021.h5ad
# scperturb/records/13350497/files/ChangYe2021.h5ad
# scperturb/records/13350497/files/ShifrutMarson2018.h5ad
# scperturb/records/13350497/files/SchiebingerLander2019_GSE106340.h5ad
# scperturb/records/13350497/files/XieHon2017.h5ad
# scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_RNA.h5ad
# scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_protein.h5ad
# scperturb/records/13350497/files/PapalexiSatija2021_eccite_protein.h5ad
# scperturb/records/13350497/files/GasperiniShendure2019_lowMOI.h5ad
# scperturb/records/13350497/files/GehringPachter2019.h5ad
# scperturb/records/13350497/files/SchiebingerLander2019_GSE115943.h5ad
# scperturb/records/13350497/files/XuCao2023.h5ad
# scperturb/records/13350497/files/PapalexiSatija2021_eccite_RNA.h5ad

# %%
unprocessed = [
    # GSE81884
    "scperturb/records/13350497/files/XieHon2017.h5ad",
    "scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_RNA.h5ad",
    "scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_protein.h5ad",
    "scperturb/records/13350497/files/PapalexiSatija2021_eccite_protein.h5ad",
    "scperturb/records/13350497/files/PapalexiSatija2021_eccite_RNA.h5ad",
    #
    "scperturb/records/13350497/files/GehringPachter2019.h5ad",
    # GSE106340 , GSE115943
    "scperturb/records/13350497/files/SchiebingerLander2019_GSE115943.h5ad",
    "scperturb/records/13350497/files/SchiebingerLander2019_GSE106340.h5ad",
    # GSE120861
    "scperturb/records/13350497/files/GasperiniShendure2019_atscale.h5ad",
    "scperturb/records/13350497/files/GasperiniShendure2019_highMOI.h5ad",
    "scperturb/records/13350497/files/GasperiniShendure2019_lowMOI.h5ad",
    "parse10m/Parse_10M_PBMC_cytokines",
]

others = [
    "scperturb/sunshine23",
    "scperturb/shifrut18",  # GSE119450
    "DRUG-seq/GSE120222",
    "scperturb/chang22",  # changye2021
    "scperturb/aissa21",  # GSE149383
    "scperturb/datlinger17",  # GSE92872
    "scperturb/datlinger21",  # GSE168620
    "scperturb/frangieh21",
    "scperturb/xu23",
    "scperturb/wessels22",
    "scperturb/zhao21",  # GSE148842
    # GSE124703
    "scperturb/tian21_CRISPRi",
    "scperturb/tian21_CRISPRa",
    # GSE153056
    "scperturb/papalexi21_eccite_arrayed_RNA",
    "scperturb/papalexi21_eccite_RNA",
    # GSE152988
    "scperturb/tian19_day7neuron",
    "scperturb/tian19_iPSC",
    "scperturb/norman19",  # GSE133344
    "scperturb/mcfarland20",
    "ginkgo-datapoints/vcpi",
]

# add gene effect and other features for mcfarland20
# redo the parse10m to follow the same schema as the others

srivatsan = [  # GSE139944
    "scperturb/srivatsan20_sciplex2",
    "scperturb/srivatsan20_sciplex3",
    "scperturb/srivatsan20_sciplex4",
]

# could be merged

gwps = [
    "scperturb/replogle22_K562_gwps",
    "scperturb/replogle22_RPE1",
    # "scperturb/replogle22_K562_essential",
]

adamson = [
    "scperturb/adamson16_GSM2406675_10X001",  # GSE90546
    "scperturb/adamson16_GSM2406677_10X005",
    "scperturb/adamson16_GSM2406681_10X010",
]

# could be merged

nadig = ["scperturb/nadig24_hepg2", "scperturb/nadig24_jurkat"]

# could be merged

dixit = [
    "scperturb/dixit16_K562_TFs_13_days",  # GSE90063
    "scperturb/dixit16_K562_TFs_7_days",
    "scperturb/dixit16_K562_TFs_High_MOI",
]

# could be merged

lincs = [
    # "lincs/phase1/Level2_GEX_delta_n49216x978",
    "lincs/phase1/Level2_GEX_epsilon_n1269922x978",
    "lincs/phase2/Level2_GEX_all_n537590x978",
]
# remaining add lincs Level4 data

tahoe = [
    # "tahoe100m/Tahoe-100M-SCVI-v1/minified_AnnData",
    "tahoe100m/2025-02-25/plate1_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate2_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate3_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate4_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate5_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate6_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate7_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate8_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate9_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate10_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate11_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate12_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate13_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
    "tahoe100m/2025-02-25/plate14_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab",
]

GSE305979 = [
    "cellarity/GSE305979/GSE305979_day0_raw_counts",
    "cellarity/GSE305979/GSE305979_day1-7_raw_counts",
    "cellarity/GSE305979/GSE305979_day0-7_normalized_counts_with_celltype_annotations",
]

# why does GSE305979_day0-7_normalized_counts contains less cells than the raw counts? maybe some filtering was done?

GSE306429 = [
    "cellarity/GSE306429/GSE306429_combined_vscores",
    "cellarity/GSE306429/GSE306429_combined_demuxed",
]


# GSE305370 = [
#    "cellarity/GSE305370/GSE305370_multiome_alldonors_alldays",
#    "cellarity/GSE305370/GSE305370_citeseq_alldonors_alldays",
# ]
# merge cite and multiome

# compute diff expr (parquet) for all datasets

# check missing annotations (overlap of obs features and unknown or empty fields)

# preprocess by computing quality metrics (mito, ribo, etc) and flagging low quality cells

# compute and find missing annotations (sex, ethnicity, pert library)

# define fingerprints for all datasets (perturbation, cell type, etc)

# get the dna seq for all patients

# compute an embedding (obsm)

# %%
for i in ln.Artifact.filter(key__contains="parse10m"):
    print(i.key)
# Out:
# parse10m/Parse_10M_PBMC_cytokines_curated.tiledbsoma
# parse10m/Parse_10M_PBMC_cytokines.h5ad

# %%
obs_artifact = ln.Artifact.get(key=GSE306429[1] + "/obs.parquet")
obs_artifact.n_observations, obs_artifact.features
# Out:
# Artifact: cellarity/GSE306429/GSE306429_combined_demuxed/obs.parquet (0000)
# ├── Dataset features
# │   └── columns (11)
# │       assay                          bionty.ExperimentalFactor            10x 3' v3
# │       cell_line                      bionty.CellLine                      A-375, A549, CD34+, CD8+, HA1E cell, H…
# │       organism                       bionty.Organism                      human
# │       pert_compound                  pertdb.Compound
# │       pert_compound_multi            list[pertdb.Compound]
# │       pert_dose                      str
# │       pert_name                      str
# │       pert_time                      str
# │       pert_type                      ULabel[380pmYI1]                     compound
# │       suspension_type                ULabel[je7xSS9z]                     cell
# │       tissue_type                    ULabel[FzEcREBL]                     cell culture
# └── External features
#     └── X                              Artifact                             cellarity/GSE306429/GSE306429_combined…
# (1257778, )

# %%
obs_artifact = db.Artifact.get(
    key="lincs/phase1/Level2_GEX_delta_n49216x978/obs.parquet"
)

# %%
obs_artifact
# Out:
# Artifact(uid='DWsyQzOmlTS19kUr0000', version_tag=None, is_latest=True, key='cellarity/GSE306429/GSE306429_combined_demuxed/obs.parquet', description=None, suffix='.parquet', kind='dataset', otype='DataFrame', size=12051619, hash='qWquoJjIzx0wuEUGN2h6rg', n_files=None, n_observations=1257778, branch_id=1, created_on_id=1, space_id=1, storage_id=1, run_id=87, schema_id=37, created_by_id=1, created_at=2025-11-13 18:57:39 UTC, is_locked=False)

# %%
# MODEL
obs_artifact = db.Artifact.get(
    key="lincs/phase1/Level2_GEX_delta_n49216x978/obs.parquet"
)
X_artifact = obs_artifact.features.get_values()["X"]
var_artifact = X_artifact.features.get_values()["var"]

adata = X_artifact.load()
adata.obs = obs_artifact.load()
adata.var = var_artifact.load()

# %% [markdown]
# # preprocessing

# %%
from tools.convert_triplet_artifacts import *
from tools.ingest_xatlas_orion import *

# %%
for ds in unprocessed:
    print(ds)
# Out:
# scperturb/records/13350497/files/XieHon2017.h5ad
# scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_RNA.h5ad
# scperturb/records/13350497/files/PapalexiSatija2021_eccite_arrayed_protein.h5ad
# scperturb/records/13350497/files/PapalexiSatija2021_eccite_protein.h5ad
# scperturb/records/13350497/files/PapalexiSatija2021_eccite_RNA.h5ad
# scperturb/records/13350497/files/GehringPachter2019.h5ad
# scperturb/records/13350497/files/SchiebingerLander2019_GSE115943.h5ad
# scperturb/records/13350497/files/SchiebingerLander2019_GSE106340.h5ad
# scperturb/records/13350497/files/GasperiniShendure2019_atscale.h5ad
# scperturb/records/13350497/files/GasperiniShendure2019_highMOI.h5ad
# scperturb/records/13350497/files/GasperiniShendure2019_lowMOI.h5ad
# parse10m/Parse_10M_PBMC_cytokines

# %%
migrate_h5ad_to_triplet(
    "scperturb/records/13350497/files/XieHon2017.h5ad", db, replace_on_instance=True
)
# Out:
# ... synchronizing XieHon2017.h5ad: 100.0%
# ! run input wasn't tracked, call `ln.track()` and re-run
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 migrate_h5ad_to_triplet(unprocessed[0], db, replace_on_instance=True)
#
# File ~/Documents/code/pert-gym/tools/convert_triplet_artifacts.py:93, in migrate_h5ad_to_triplet(dataset_name, db, replace_on_instance)
#      90 prev_x = list(db.Artifact.filter(key=x_key).all())
#      91 prev_var = list(db.Artifact.filter(key=var_key).all())
# ---> 93 obs_artifact = db.Artifact.from_dataframe(
#      94     obs_df,
#      95     key=obs_key,
#      96     revises=prev_obs[-1] if (replace_on_instance and prev_obs) else None,
#      97 ).save()
#      98 x_artifact = db.Artifact.from_anndata(
#      99     x_adata,
#     100     key=x_key,
#     101     revises=prev_x[-1] if (replace_on_instance and prev_x) else None,
#     102 ).save()
#     103 var_artifact = db.Artifact.from_dataframe(
#     104     var_df,
#     105     key=var_key,
#     106     revises=prev_var[-1] if (replace_on_instance and prev_var) else None,
#     107 ).save()
#
# File ~/Documents/code/pert-gym/.venv/lib/python3.11/site-packages/lamindb/models/query_set.py:1431, in NonInstantiableQuerySet.__getattr__(self, attr)
#    1430 def __getattr__(self, attr):
# -> 1431     return getattr(self._qs, attr)
#
# AttributeError: 'ArtifactQuerySet' object has no attribute 'from_dataframe'

# %%
from tools.ingest_xatlas_orion import (
    download_xatlas_orion,
    preprocess_xatlas_orion,
    save_xatlas_orion,
)

download_xatlas_orion()
adatas = preprocess_xatlas_orion()
results = save_xatlas_orion(adatas)
print(results)

# %%
db.bionty.Organism.filter().to_dataframe(limit=None)
# Out:
#                uid   name      ontology_id  abbr synonyms description  \
# id
# 2   3RZqbcSLWNGQGZ  mouse  NCBITaxon:10090  None     None        None
# 1   1dpCL6TduFJ3AP  human   NCBITaxon:9606  None     None        None
#
#    scientific_name  is_locked                       created_at  branch_id  \
# id
# 2     Mus musculus      False 2025-01-10 09:10:26.654102+00:00          1
# 1     Homo sapiens      False 2025-01-10 09:09:31.662158+00:00          1
#
#     space_id  created_by_id  run_id  source_id
# id
# 2          1              1       1          1
# 1          1              1       1          1

# %%
db.bionty.Gene.filter().to_dataframe(limit=None)
# Out:
#                    uid  abbr                              synonyms  \
# id
# 132480  4s1Zf4HuctP7KS  None                                  None
# 132479  60sc1BU8AnSk4S  None                                  None
# 132478  64l1gcpbVwxujl  None                                  None
# 132477  6dmaRYJ3K9FA0J  None                                  None
# 132476  5TKpJ4YHvun1Ye  None                                  None
# ...                ...   ...                                   ...
# 5       3wEqb6eOTZzC42  None  C1ORF112|FLJ10706|APOLO1|FLIP|MEICA1
# 4       5Zug63FETk4pJF  None                          PACE1|PACE-1
# 3       4eC1wUNJAO2s7T  None                            CDGIE|MPDS
# 2       2FhduD7Z97Uvq1  None      TEM|MYODULIN|CHM1L|TENDIN|BRICD4
# 1       1uTi9dROoaN5rR  None                   TSPAN-6|T245|TM4SF6
#
#                                               description  symbol stable_id  \
# id
# 132480                                               None    None      None
# 132479                                               None    None      None
# 132478                                               None    None      None
# 132477                                               None    None      None
# 132476                                               None    None      None
# ...                                                   ...     ...       ...
# 5       FIGNL1 interacting regulator of recombination ...   FIRRM      None
# 4                               SCY1 like pseudokinase 3    SCYL3      None
# 3       dolichyl-phosphate mannosyltransferase subunit...    DPM1      None
# 2                                            tenomodulin     TNMD      None
# 1                                          tetraspanin 6   TSPAN6      None
#
#         ensembl_gene_id ncbi_gene_ids         biotype  is_locked  \
# id
# 132480  ENSG00000284737          None            None      False
# 132479  ENSG00000284714          None            None      False
# 132478  ENSG00000284683          None            None      False
# 132477  ENSG00000284561          None            None      False
# 132476  ENSG00000284486          None            None      False
# ...                 ...           ...             ...        ...
# 5       ENSG00000000460         55732  protein_coding      False
# 4       ENSG00000000457         57147  protein_coding      False
# 3       ENSG00000000419          8813  protein_coding      False
# 2       ENSG00000000005         64102  protein_coding      False
# 1       ENSG00000000003          7105  protein_coding      False
#
#                              created_at  branch_id  space_id  created_by_id  \
# id
# 132480 2025-01-17 07:14:19.138328+00:00          1         1              1
# 132479 2025-01-17 07:14:19.138328+00:00          1         1              1
# 132478 2025-01-17 07:14:19.138328+00:00          1         1              1
# 132477 2025-01-17 07:14:19.138328+00:00          1         1              1
# 132476 2025-01-17 07:14:19.138328+00:00          1         1              1
# ...                                 ...        ...       ...            ...
# 5      2025-01-10 09:09:58.273264+00:00          1         1              1
# 4      2025-01-10 09:09:58.273239+00:00          1         1              1
# 3      2025-01-10 09:09:58.273204+00:00          1         1              1
# 2      2025-01-10 09:09:58.273178+00:00          1         1              1
# 1      2025-01-10 09:09:58.273110+00:00          1         1              1
#
#         run_id  source_id  organism_id
# id
# 132480      51        NaN            1
# 132479      51        NaN            1
# 132478      51        NaN            1
# 132477      51        NaN            1
# 132476      51        NaN            1
# ...        ...        ...          ...
# 5            1       11.0            1
# 4            1       11.0            1
# 3            1       11.0            1
# 2            1       11.0            1
# 1            1       11.0            1
#
# [132413 rows x 17 columns]
